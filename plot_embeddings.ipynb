# %%
import pickle
from sklearn import manifold
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
with open("embeddings.pickle", 'rb') as f:
    [store_embedding, dow_embedding, year_embedding,
     month_embedding, day_embedding, german_states_embedding] = pickle.load(f)

# %%
# Load LabelEncoders
with open("les.pickle", 'rb') as f:
    les = pickle.load(f)
le_store = les[1]
le_dow = les[2]
le_month = les[5]
le_day = les[6]
le_state = les[7]

# %%
list(le_state.classes_)
# Out:
# ['BE', 'BW', 'BY', 'HB,NI', 'HE', 'HH', 'NW', 'RP', 'SH', 'SN', 'ST', 'TH']

# %%
states_names = ['Berlin', 'Baden Wuerttemberg', 'Bayern', 'Niedersachsen/Bremen', 
                'Hessen', 'Hamburg', 'Nordrhein Westfalen', 'Rheinland Pfalz',
                'Schleswig Holstein', 'Sachsen', 'Sachsen Anhalt', 'Thueringen']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact')
Y = tsne.fit_transform(german_states_embedding)
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(states_names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-20, 8), textcoords = 'offset points')
plt.savefig('state_embedding.pdf')

# %%
list(le_dow.classes_)
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact')
Y = tsne.fit_transform(dow_embedding)
names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')
plt.savefig('dow_embedding.png')

# %%
list(le_month.classes_)
# Out:
# ['1', '10', '11', '12', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
# mine 
tsne = manifold.TSNE(init='pca', random_state=0, method='exact')
Y = tsne.fit_transform(month_embedding)
names = ['Jan', 'Oct', 'Nov', 'Dec', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')
plt.savefig('month_embedding.png')

# %%
# authors
tsne = manifold.TSNE(init='pca', random_state=0, method='exact')
Y = tsne.fit_transform(month_embedding)
names = ['Jan', 'Oct', 'Nov', 'Dec', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')
plt.savefig('month_embedding.png')

# %%
# store_embedding
tsne = manifold.TSNE(init='pca', random_state=0, method='exact', 
                     learning_rate=500, verbose=2, early_exaggeration=1)
Y = tsne.fit_transform(store_embedding)

names = list(le_store.classes_)
plt.figure(figsize=(20,20))
plt.scatter(-Y[:, 0], -Y[:, 1])

for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]))

plt.savefig('store_embedding.png')
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1115
# [t-SNE] Computed conditional probabilities for sample 1115 / 1115
# [t-SNE] Mean sigma: 0.093884
# [t-SNE] Iteration 50: error = 1.4033701, gradient norm = 0.0013911 (50 iterations in 2.074s)
# [t-SNE] Iteration 100: error = 1.3294497, gradient norm = 0.0006155 (50 iterations in 2.198s)
# [t-SNE] Iteration 150: error = 1.3012991, gradient norm = 0.0003715 (50 iterations in 2.233s)
# [t-SNE] Iteration 200: error = 1.2868803, gradient norm = 0.0002431 (50 iterations in 2.050s)
# [t-SNE] Iteration 250: error = 1.2783110, gradient norm = 0.0001701 (50 iterations in 2.408s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 1.278311
# [t-SNE] Iteration 300: error = 1.2715691, gradient norm = 0.0001306 (50 iterations in 1.895s)
# [t-SNE] Iteration 350: error = 1.2645488, gradient norm = 0.0000760 (50 iterations in 1.797s)
# [t-SNE] Iteration 400: error = 1.2610334, gradient norm = 0.0000554 (50 iterations in 1.805s)
# [t-SNE] Iteration 450: error = 1.2590866, gradient norm = 0.0000410 (50 iterations in 1.819s)
# [t-SNE] Iteration 500: error = 1.2578745, gradient norm = 0.0000342 (50 iterations in 1.791s)
# [t-SNE] Iteration 550: error = 1.2570477, gradient norm = 0.0000269 (50 iterations in 1.804s)
# [t-SNE] Iteration 600: error = 1.2564492, gradient norm = 0.0000256 (50 iterations in 1.843s)
# [t-SNE] Iteration 650: error = 1.2559998, gradient norm = 0.0000212 (50 iterations in 1.860s)
# [t-SNE] Iteration 700: error = 1.2556485, gradient norm = 0.0000198 (50 iterations in 1.962s)
# [t-SNE] Iteration 750: error = 1.2553653, gradient norm = 0.0000166 (50 iterations in 1.807s)
# [t-SNE] Iteration 800: error = 1.2551326, gradient norm = 0.0000163 (50 iterations in 1.862s)
# [t-SNE] Iteration 850: error = 1.2549338, gradient norm = 0.0000154 (50 iterations in 1.953s)
# [t-SNE] Iteration 900: error = 1.2547669, gradient norm = 0.0000138 (50 iterations in 1.967s)
# [t-SNE] Iteration 950: error = 1.2546226, gradient norm = 0.0000128 (50 iterations in 1.972s)
# [t-SNE] Iteration 1000: error = 1.2544965, gradient norm = 0.0000113 (50 iterations in 2.034s)
# [t-SNE] KL divergence after 1000 iterations: 1.254497

# %%
# store_embedding
tsne = manifold.TSNE(init='pca', random_state=0, method='exact', learning_rate=500, verbose=2, early_exaggeration=1)
Y = tsne.fit_transform(store_embedding)

names = list(le_store.classes_)
plt.figure(figsize=(20,20))
plt.scatter(-Y[:, 0], -Y[:, 1])

for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]))

plt.savefig('store_embedding.png')
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1115
# [t-SNE] Computed conditional probabilities for sample 1115 / 1115
# [t-SNE] Mean sigma: 0.372075
# [t-SNE] Iteration 25: error = 2.0486918, gradient norm = 0.0091871
# [t-SNE] Iteration 50: error = 2.0328715, gradient norm = 0.0101395
# [t-SNE] Iteration 75: error = 1.8416205, gradient norm = 0.0019665
# [t-SNE] Iteration 100: error = 1.8118919, gradient norm = 0.0022891
# [t-SNE] Error after 100 iterations with early exaggeration: 1.811892
# [t-SNE] Iteration 125: error = 1.7666324, gradient norm = 0.0010000
# [t-SNE] Iteration 150: error = 1.7539868, gradient norm = 0.0016297
# [t-SNE] Iteration 175: error = 1.7516267, gradient norm = 0.0019987
# [t-SNE] Iteration 200: error = 1.7510424, gradient norm = 0.0022504
# [t-SNE] Iteration 225: error = 1.7534914, gradient norm = 0.0028039
# [t-SNE] Iteration 250: error = 1.7573196, gradient norm = 0.0031417
# [t-SNE] Iteration 275: error = 1.7588523, gradient norm = 0.0026925
# [t-SNE] Iteration 275: did not make any progress during the last 50 episodes. Finished.
# [t-SNE] Error after 275 iterations: 1.758852
